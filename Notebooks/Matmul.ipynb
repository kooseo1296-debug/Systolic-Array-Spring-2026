# %%
from pynq import Overlay
ol = Overlay("./design_top.bit")

# %%
# ol?
top = ol.top_0

# %%
def dec_to_tc(data, bit=8):
    if data >= 0:
        return data
    else:
        datatc = pow(2,bit-1) + (pow(2,bit-1)+data)
        return int(datatc)
def tc_to_dec(data, bit=32):
    if data >= pow(2,bit-1):
        datadec = data-2*pow(2,bit-1)
        return int(datadec)
    else:
        return data
def instr_param(opvalid, opcode, param, data):
    _instr = opvalid * pow(2,31)
    _instr += opcode * pow(2,28)
    _instr += param * pow(2,8)
    _instr += data * pow(2,0)
    return int(_instr)    

def instr_data(opvalid, opcode, sel, addr, data):
    _instr = opvalid * pow(2,31)
    _instr += opcode * pow(2,28)
    _instr += sel * pow(2,24)
    _instr += addr * pow(2,8)
#     _instr += data * pow(2,0)
    _instr += dec_to_tc(data)
    return int(_instr)
def pl_rst():
    top.mmio.write(offset=0, data=dec_to_tc(data=-1,bit=32))
    top.mmio.write(offset=0, data=0)

# %%
# parameters setting
OPCODE_NOP = 0
OPCODE_PARAM = 1
OPCODE_LDSRAM = 2
OPCODE_STSRAM = 3
OPCODE_EX = 4
OPCODE_WBPSRAM = 5
OPCODE_WBPARAM = 6

PARAM_BASE_WSRAM = 0
PARAM_S = 1
PARAM_OC = 2
PARAM_IC = 3
PARAM_TRG = 4

TRG_ISRAM = 0
TRG_WSRAM = 1
TRG_PSRAM = 2

# %%
# Init
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_S, data=4))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_OC, data=5))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_IC, data=23))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_WBPARAM, param=PARAM_S, data=0))
print(top.mmio.read(offset=12))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_WBPARAM, param=PARAM_OC, data=0))
print(top.mmio.read(offset=12))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_WBPARAM, param=PARAM_IC, data=0))
print(top.mmio.read(offset=12))
# Out:
# 4
# 5
# 23

# %%
# LDSRAM_I
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_TRG, data=TRG_ISRAM))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=0, data=-112))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=0, data=-117))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=0, data=101))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=0, data=124))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=0, data=28))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=0, data=53))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=0, data=-2))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=0, data=62))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=4, data=26))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=4, data=124))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=4, data=100))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=4, data=110))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=4, data=-17))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=4, data=37))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=4, data=22))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=4, data=-13))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=8, data=-73))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=8, data=3))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=8, data=125))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=8, data=84))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=8, data=-88))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=8, data=81))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=8, data=79))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=1, data=105))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=1, data=-58))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=1, data=-120))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=1, data=-36))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=1, data=5))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=1, data=-122))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=1, data=108))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=1, data=-57))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=5, data=97))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=5, data=8))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=5, data=-6))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=5, data=-112))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=5, data=84))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=5, data=-79))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=5, data=16))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=5, data=115))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=9, data=82))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=9, data=57))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=9, data=-27))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=9, data=15))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=9, data=4))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=9, data=-95))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=9, data=46))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=2, data=-97))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=2, data=-57))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=2, data=10))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=2, data=-40))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=2, data=-66))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=2, data=65))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=2, data=-109))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=2, data=-55))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=6, data=43))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=6, data=61))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=6, data=-89))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=6, data=-66))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=6, data=91))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=6, data=-109))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=6, data=-65))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=6, data=-65))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=10, data=-13))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=10, data=118))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=10, data=-106))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=10, data=86))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=10, data=-54))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=10, data=-65))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=10, data=-94))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=3, data=-23))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=3, data=-93))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=3, data=-67))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=3, data=-2))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=3, data=84))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=3, data=87))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=3, data=-78))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=3, data=-64))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=7, data=84))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=7, data=48))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=7, data=122))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=7, data=58))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=7, data=-78))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=7, data=-104))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=7, data=50))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=7, addr=7, data=-11))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=11, data=126))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=11, data=-41))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=11, data=-113))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=11, data=12))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=11, data=63))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=5, addr=11, data=77))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=6, addr=11, data=37))



# LDSRAM_W
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_TRG, data=TRG_WSRAM))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=0, data=89))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=1, data=-33))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=2, data=-92))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=3, data=-17))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=4, data=44))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=5, data=25))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=6, data=19))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=7, data=-60))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=8, data=61))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=9, data=105))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=10, data=-70))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=11, data=-9))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=12, data=55))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=13, data=18))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=14, data=-12))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=15, data=37))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=16, data=118))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=17, data=109))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=18, data=-74))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=19, data=-5))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=20, data=42))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=21, data=110))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=0, addr=22, data=46))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=0, data=-107))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=1, data=102))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=2, data=-103))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=3, data=-28))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=4, data=39))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=5, data=113))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=6, data=102))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=7, data=-25))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=8, data=29))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=9, data=-120))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=10, data=-68))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=11, data=-82))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=12, data=-124))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=13, data=-41))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=14, data=-43))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=15, data=-21))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=16, data=-127))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=17, data=-65))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=18, data=52))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=19, data=111))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=20, data=10))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=21, data=-23))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=22, data=-82))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=0, data=104))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=1, data=-17))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=2, data=60))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=3, data=106))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=4, data=-88))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=5, data=82))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=6, data=-7))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=7, data=88))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=8, data=60))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=9, data=55))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=10, data=-45))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=11, data=-7))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=12, data=113))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=13, data=74))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=14, data=-46))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=15, data=-88))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=16, data=31))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=17, data=17))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=18, data=29))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=19, data=126))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=20, data=-97))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=21, data=99))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=2, addr=22, data=27))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=0, data=-103))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=1, data=69))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=2, data=110))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=3, data=-79))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=4, data=-35))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=5, data=-113))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=6, data=3))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=7, data=85))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=8, data=-35))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=9, data=-16))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=10, data=79))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=11, data=24))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=12, data=-102))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=13, data=-88))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=14, data=112))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=15, data=-65))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=16, data=-31))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=17, data=104))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=18, data=42))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=19, data=87))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=20, data=-34))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=21, data=69))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=3, addr=22, data=70))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=0, data=25))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=1, data=-97))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=2, data=-70))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=3, data=124))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=4, data=27))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=5, data=27))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=6, data=-68))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=7, data=109))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=8, data=3))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=9, data=-61))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=10, data=-90))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=11, data=29))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=12, data=-35))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=13, data=-96))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=14, data=99))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=15, data=-87))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=16, data=46))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=17, data=-81))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=18, data=-31))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=19, data=1))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=20, data=-92))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=21, data=-56))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=4, addr=22, data=-87))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=23, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=24, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=25, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=26, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=27, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=28, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=29, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=30, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=31, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=32, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=33, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=34, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=35, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=36, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=37, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=38, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=39, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=40, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=41, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=42, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=43, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=44, data=0))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_LDSRAM, sel=1, addr=45, data=0))

# %%
# Execute
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_BASE_WSRAM, data=0))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_EX, param=0, data=0))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_NOP, param=0, data=0))

# %%
# Writeback
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
# Out:
# -22215
# 50645
# 15228
# 40901
# -22847
# -19173
# 9097
# -19732
# 51641
# -19155
# 21261
# -22490
# 41749
# -29981
# -7084
# -5071
# 2287
# -10254
# 17839
# 21785

# %%
# Init
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_S, data=4))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_OC, data=5))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_IC, data=6))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_WBPARAM, param=PARAM_S, data=0))
print(top.mmio.read(offset=12))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_WBPARAM, param=PARAM_OC, data=0))
print(top.mmio.read(offset=12))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_WBPARAM, param=PARAM_IC, data=0))
print(top.mmio.read(offset=12))

# Execute
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_PARAM, param=PARAM_BASE_WSRAM, data=0))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_EX, param=0, data=0))
top.mmio.write(offset=0, data=instr_param(opvalid=1, opcode=OPCODE_NOP, param=0, data=0))

# Writeback
print("---------")
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=0, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=1, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=2, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=3, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=0, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=1, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=2, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
top.mmio.write(offset=0, data=instr_data(opvalid=1, opcode=OPCODE_WBPSRAM, sel=4, addr=3, data=0))
print(tc_to_dec(data=top.mmio.read(offset=12),bit=32))
# Out:
# 4
# 5
# 6
# ---------
# -14950
# 20081
# -8271
# 13091
# -6744
# -17374
# 9426
# 13039
# 11427
# -9554
# -1621
# -5301
# -2192
# -11562
# 5283
# -24031
# 19042
# 9028
# -2583
# 17505
